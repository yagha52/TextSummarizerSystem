# %% [markdown]
# # 🧪 Hyperparameter Experiment Log
#
# Track your experiments here to find the best configuration for your summarizer.
#
# | Experiment ID | Learning Rate | LoRA Rank | Batch Size | Epochs | Validation Loss | ROUGE-1 |
# |--------------|---------------|-----------|------------|--------|-----------------|---------|
# | Base Run     | 2e-4          | 16        | 1          | 3      | *pending...*    | *pending* |
# | Exp 1        | 1e-4          | 32        | 2          | 3      |                 |         |
# | Exp 2        | 5e-4          | 16        | 4          | 2      |                 |         |
